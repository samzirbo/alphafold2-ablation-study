# %%
! nvidia-smi

# %%
! git clone https://github.com/samzirbo/alphafold2-ablation-study
# %cd alphafold2-ablation-study

# %%
! git checkout sam/feat/refactor-colabfold-as-script

# %%
! uv sync

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
! uv run scripts/predict.py --job baseline --input LAT1 ZnT8 --num-models 5 --num-seeds 5 --drive "/content/drive/MyDrive/Masters/Semester 3/AlphaFold2 Ablation Study/04_Results"
