# %%
! git clone https://github.com/samzirbo/alphafold2-ablation-study
# %cd alphafold2-ablation-study
# Out:
# Cloning into 'alphafold2-ablation-study'...
# remote: Enumerating objects: 450, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 450 (delta 31), reused 36 (delta 22), pack-reused 365 (from 1)
# Receiving objects: 100% (450/450), 44.36 MiB | 11.94 MiB/s, done.
# Resolving deltas: 100% (208/208), done.
# /content/alphafold2-ablation-study

# %%
! uv sync

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
base_drive_path = "/content/drive/MyDrive/AlphaFold2 Ablation Study"
base_repo_path = "/content/alphafold2-ablation-study"
result_path = base_drive_path + "/04_Results/" if base_drive_path[-1] != "/" else base_drive_path + "04_Results/"

# %%
# !uv run scripts/auto_plot.py \
    --result_path "$result_path" \
    --base_repo_path "$base_repo_path"
# Out:
# /content/drive/MyDrive/AlphaFold2 Ablation Study/04_Results/ /content/alphafold2-ablation-study
# ['/content/drive/MyDrive/AlphaFold2 Ablation Study/04_Results/archive', '/content/drive/MyDrive/AlphaFold2 Ablation Study/04_Results/depth_256', '/content/drive/MyDrive/AlphaFold2 Ablation Study/04_Results/depth_128', '/content/drive/MyDrive/AlphaFold2 Ablation Study/04_Results/depth_16', '/content/drive/MyDrive/AlphaFold2 Ablation Study/04_Results/depth_5120', '/content/drive/MyDrive/AlphaFold2 Ablation Study/04_Results/col_mask_5', '/content/drive/MyDrive/AlphaFold2 Ablation Study/04_Results/col_mask_15', '/content/drive/MyDrive/AlphaFold2 Ablation Study/04_Results/depth_32', '/content/drive/MyDrive/AlphaFold2 Ablation Study/04_Results/col_mask_30', '/content/drive/MyDrive/AlphaFold2 Ablation Study/04_Results/col_mask_50', '/content/drive/MyDrive/AlphaFold2 Ablation Study/04_Results/row_mask_128', '/content/drive/MyDrive/AlphaFold2 Ablation Study/04_Results/qu_mask_15MurJ_missing', '/content/drive/MyDrive/AlphaFold2 Ablation Study/04_Results/row_mask_32', '/content/drive/MyDrive/AlphaFold2 Ablation Study/04_Results/row_mask_512', '/content/drive/MyDrive/AlphaFold2 Ablation Study/04_Results/plots']
# /content/drive/MyDrive/AlphaFold2 Ablation Study/04_Results/plots/TM_Score/msa_depth_256_ASCT2_CCR5
# Saving fugure at:  /content/drive/MyDrive/AlphaFold2 Ablation Study/04_Results/plots/TM_Score/msa_depth_256_ASCT2_CCR5/ASCT2.png
# /content/drive/MyDrive/AlphaFold2 Ablation Study/04_Results/plots/TM_Score/msa_depth_256_ASCT2_CCR5
# Saving fugure at:  /content/drive/MyDrive/AlphaFold2 Ablation Study/04_Results/plots/TM_Score/msa_depth_256_ASCT2_CCR5/CCR5.png
# /content/drive/MyDrive/AlphaFold2 Ablation Study/04_Results/plots/TM_Score/msa_depth_256_CGRPR_FZD7
# Saving fugure at:  /content/drive/MyDrive/AlphaFold2 Ablation Study/04_Results/plots/TM_Score/msa_depth_256_CGRPR_FZD7/CGRPR.png
