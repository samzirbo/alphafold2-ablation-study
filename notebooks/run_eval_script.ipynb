# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
! nvidia-smi

# %%
! git clone https://github.com/samzirbo/alphafold2-ablation-study
# %cd alphafold2-ablation-study

# %%
! git checkout benne/feat/tm_score_statistic

# %%
! uv sync

# %%
# ! uv run scripts/create_tm_score_statistic.py --help

# %%
! uv run scripts/create_tm_score_statistic.py --data_dir '/content/drive/MyDrive/AlphaFold2 Ablation Study/04_Results/plots/TM_Score' \
  --output_md '/content/drive/MyDrive/AlphaFold2 Ablation Study/04_Results/auto_eval/testName.md' \
  --experiment_include 'depth_5120' \
  --experiment_include 'query_mask_5' \
  --experiment_include 'query_mask_10' \

  # --output_md '/content/drive/MyDrive/bla2/testName.md' \


# usage: create_tm_score_statistic.py [-h] [-i DATA_DIR] [-o OUTPUT_MD]
#                                     [--experiment_include EXPERIMENT_INCLUDE [EXPERIMENT_INCLUDE ...]]
#                                     [--experiment_exclude EXPERIMENT_EXCLUDE [EXPERIMENT_EXCLUDE ...]]

# Process ablation experiment evaluation logs.

# options:
#   -h, --help            show this help message and exit
#   -i DATA_DIR, --data_dir DATA_DIR
#                         Path to the directory containing evaluation CSV files.
#   -o OUTPUT_MD, --output_md OUTPUT_MD
#                         Path to output markdown file. Defaults to
#                         '/content/drive/MyDrive/AlphaFold2 Ablation Study/04_R
#                         esults/plots/TM_Score/ablation_report_2026-07-04.md'
#                         if omitted.
#   --experiment_include EXPERIMENT_INCLUDE [EXPERIMENT_INCLUDE ...]
#                         One or more substrings. Only process subfolders that
#                         contain at least one of these strings.
#   --experiment_exclude EXPERIMENT_EXCLUDE [EXPERIMENT_EXCLUDE ...]
#                         One or more substrings. Completely skip subfolders
#                         containing any of these strings.
# Out:
# [Success] Unified report saved to: /content/drive/MyDrive/AlphaFold2 Ablation Study/04_Results/auto_eval/testName.md
